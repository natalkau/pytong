# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from statistics import mean

# %%
a = pd.read_csv(r'/content/sample_data/mnist_test.csv')

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
aa = pd.read_csv(r'/content/data.csv')

# %%
aa
# Out:
#       Imię  Kurs_1  Kurs_2  Kurs_3
# 0    Marta       5     4.5     5.0
# 1    Piotr       4     4.0     3.5
# 2    Jakub       3     3.0     4.0
# 3     Anna       4     5.0     4.0
# 4   Michał       5     4.0     3.5
# 5   Emilia       3     3.0     2.0
# 6  Tadeusz       3     4.0     4.0

# %%
df = pd.DataFrame(aa)

# %%
df
# Out:
#       Imię  Kurs_1  Kurs_2  Kurs_3
# 0    Marta       5     4.5     5.0
# 1    Piotr       4     4.0     3.5
# 2    Jakub       3     3.0     4.0
# 3     Anna       4     5.0     4.0
# 4   Michał       5     4.0     3.5
# 5   Emilia       3     3.0     2.0
# 6  Tadeusz       3     4.0     4.0

# %%
df.sort_values(by=['Imię'])
# Out:
#       Imię  Kurs_1  Kurs_2  Kurs_3
# 3     Anna       4     5.0     4.0
# 5   Emilia       3     3.0     2.0
# 2    Jakub       3     3.0     4.0
# 0    Marta       5     4.5     5.0
# 4   Michał       5     4.0     3.5
# 1    Piotr       4     4.0     3.5
# 6  Tadeusz       3     4.0     4.0

# %%
df.columns
# Out:
# Index(['Imię', 'Kurs_1', 'Kurs_2', 'Kurs_3'], dtype='object')

# %%
df.columns=['Imie','Kurs pierwszy','Kurs drugi','Kurs trzeci']

# %%
df
# Out:
#       Imie  Kurs pierwszy  Kurs drugi  Kurs trzeci
# 0    Marta              5         4.5          5.0
# 1    Piotr              4         4.0          3.5
# 2    Jakub              3         3.0          4.0
# 3     Anna              4         5.0          4.0
# 4   Michał              5         4.0          3.5
# 5   Emilia              3         3.0          2.0
# 6  Tadeusz              3         4.0          4.0

# %%
df.insert(4,"Losowa ocena", random.randint(2,5), True)

# %%
df
# Out:
#       Imie  Kurs pierwszy  Kurs drugi  Kurs trzeci Losowa ocena2  Losowa ocena
# 0    Marta              5         4.5          5.0          None             2
# 1    Piotr              4         4.0          3.5          None             2
# 2    Jakub              3         3.0          4.0          None             2
# 3     Anna              4         5.0          4.0          None             2
# 4   Michał              5         4.0          3.5          None             2
# 5   Emilia              3         3.0          2.0          None             2
# 6  Tadeusz              3         4.0          4.0          None             2

# %%
df.drop("Losowa ocena2",axis='columns')
# Out:
#       Imie  Kurs pierwszy  Kurs drugi  Kurs trzeci  Losowa ocena
# 0    Marta              5         4.5          5.0             2
# 1    Piotr              4         4.0          3.5             2
# 2    Jakub              3         3.0          4.0             2
# 3     Anna              4         5.0          4.0             2
# 4   Michał              5         4.0          3.5             2
# 5   Emilia              3         3.0          2.0             2
# 6  Tadeusz              3         4.0          4.0             2

# %%
df["Random"]=random.randint(2,5)

# %%
df
# Out:
#       Imie  Kurs pierwszy  Kurs drugi  Kurs trzeci Losowa ocena2  \
# 0    Marta              5         4.5          5.0          None
# 1    Piotr              4         4.0          3.5          None
# 2    Jakub              3         3.0          4.0          None
# 3     Anna              4         5.0          4.0          None
# 4   Michał              5         4.0          3.5          None
# 5   Emilia              3         3.0          2.0          None
# 6  Tadeusz              3         4.0          4.0          None
#
#    Losowa ocena  Random
# 0             2       4
# 1             2       4
# 2             2       4
# 3             2       4
# 4             2       4
# 5             2       4
# 6             2       4

# %%
randomowe=[]
np.random.seed(72)
#j=range(6)
j = 0
while j <= 6:
        randomowe.append(j)
        j = j+1
return randomowe
# Out:
#   File "<ipython-input-57-df5048a92de9>", line 7
#     return randomowe
#     ^
# SyntaxError: 'return' outside function

# %%
randomowe=[]
#j=range(6)

j = 0
while j<= 6:
        np.random.seed(17)
        randomowe.append(random.randint(2,5))
        j = j+1
print(randomowe)
# Out:
# [3, 4, 5, 3, 4, 4, 4]
